# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
## Import neccesary modules
import pandas as pd
import numpy as np
from sklearn.preprocessing  import StandardScaler

# %%
## Load the Dataset
df = pd.read_csv('/content/drive/MyDrive/PrognosAI/milestone_1/Day_1/cmapss_cleaned_train_FD001.csv')
df.head()
# Out:
#    engine_id  cycle  op_setting_1  op_setting_2  op_setting_3  sensor_1  \
# 0          1      1       -0.0007       -0.0004         100.0    518.67
# 1          1      2        0.0019       -0.0003         100.0    518.67
# 2          1      3       -0.0043        0.0003         100.0    518.67
# 3          1      4        0.0007        0.0000         100.0    518.67
# 4          1      5       -0.0019       -0.0002         100.0    518.67
#
#    sensor_2  sensor_3  sensor_4  sensor_5  ...  sensor_12  sensor_13  \
# 0    641.82   1589.70   1400.60     14.62  ...     521.66    2388.02
# 1    642.15   1591.82   1403.14     14.62  ...     522.28    2388.07
# 2    642.35   1587.99   1404.20     14.62  ...     522.42    2388.03
# 3    642.35   1582.79   1401.87     14.62  ...     522.86    2388.08
# 4    642.37   1582.85   1406.22     14.62  ...     522.19    2388.04
#
#    sensor_14  sensor_15  sensor_16  sensor_17  sensor_18  sensor_19  \
# 0    8138.62     8.4195       0.03        392       2388      100.0
# 1    8131.49     8.4318       0.03        392       2388      100.0
# 2    8133.23     8.4178       0.03        390       2388      100.0
# 3    8133.83     8.3682       0.03        392       2388      100.0
# 4    8133.80     8.4294       0.03        393       2388      100.0
#
#    sensor_20  sensor_21
# 0      39.06    23.4190
# 1      39.00    23.4236
# 2      38.95    23.3442
# 3      38.88    23.3739
# 4      38.90    23.4044
#
# [5 rows x 26 columns]

# %% [markdown]
# # Aggregate Features – Mean, Std, Min, Max per Engine

# %%
# Sensor columns
sensor_cols = [col for col in df.columns if 'sensor_' in col]

# %%
# Engine-wise aggregate feature (static for each engine)
engine_aggs = df.groupby('engine_id')[sensor_cols].agg(['mean', 'std', 'min', 'max'])
engine_aggs.columns = ['_'.join(col) for col in engine_aggs.columns]
engine_aggs.reset_index(inplace=True)
print("Aggregate feature matrix shape: {engine_aggs.shape}")
engine_aggs.head()
# Out:
# Aggregate feature matrix shape: {engine_aggs.shape}
#    engine_id  sensor_1_mean  sensor_1_std  sensor_1_min  sensor_1_max  \
# 0          1         518.67           0.0        518.67        518.67
# 1          2         518.67           0.0        518.67        518.67
# 2          3         518.67           0.0        518.67        518.67
# 3          4         518.67           0.0        518.67        518.67
# 4          5         518.67           0.0        518.67        518.67
#
#    sensor_2_mean  sensor_2_std  sensor_2_min  sensor_2_max  sensor_3_mean  \
# 0     642.621042      0.486795        641.71        644.21    1589.485521
# 1     642.435226      0.560214        641.27        643.94    1588.181986
# 2     642.543743      0.474190        641.48        643.93    1588.715084
# 3     642.662381      0.441446        641.81        644.53    1590.563280
# 4     642.451970      0.551542        641.30        644.02    1588.153271
#
#    ...  sensor_19_min  sensor_19_max  sensor_20_mean  sensor_20_std  \
# 0  ...          100.0          100.0       38.840052       0.166998
# 1  ...          100.0          100.0       38.901150       0.199332
# 2  ...          100.0          100.0       38.882793       0.166112
# 3  ...          100.0          100.0       38.830265       0.159302
# 4  ...          100.0          100.0       38.891078       0.187133
#
#    sensor_20_min  sensor_20_max  sensor_21_mean  sensor_21_std  sensor_21_min  \
# 0          38.34          39.18       23.306310       0.105101        22.9588
# 1          38.23          39.24       23.338997       0.114796        22.9721
# 2          38.37          39.23       23.321931       0.104734        22.9562
# 3          38.29          39.21       23.294502       0.093804        23.0135
# 4          38.34          39.29       23.336284       0.112705        23.0195
#
#    sensor_21_max
# 0        23.4999
# 1        23.6005
# 2        23.5181
# 3        23.5074
# 4        23.5503
#
# [5 rows x 85 columns]

# %% [markdown]
# # Rolling Statistics and Trends

# %%
# Add rolling means (window=5 cycles) and rolling std for each sensor per engine
for col in sensor_cols:
  df[f"{col}_rollmean5"] = df.groupby('engine_id')[col].rolling(window=5, min_periods=1).mean().reset_index(level=0,drop=True)
  df[f"{col}_rollstd5"] = df.groupby('engine_id')[col].rolling(window=5, min_periods=1).std().reset_index(level=0,drop=True)

# Prepare the list of columns to display
cols_to_show = sensor_cols + [f"{col}_rollmean5" for col in  sensor_cols] + [f"{col}_rollstd5" for col in sensor_cols]

# Display the first 10 rows of the selected columns
df[cols_to_show].head(10)
# Out:
#    sensor_1  sensor_2  sensor_3  sensor_4  sensor_5  sensor_6  sensor_7  \
# 0    518.67    641.82   1589.70   1400.60     14.62     21.61    554.36
# 1    518.67    642.15   1591.82   1403.14     14.62     21.61    553.75
# 2    518.67    642.35   1587.99   1404.20     14.62     21.61    554.26
# 3    518.67    642.35   1582.79   1401.87     14.62     21.61    554.45
# 4    518.67    642.37   1582.85   1406.22     14.62     21.61    554.00
# 5    518.67    642.10   1584.47   1398.37     14.62     21.61    554.67
# 6    518.67    642.48   1592.32   1397.77     14.62     21.61    554.34
# 7    518.67    642.56   1582.96   1400.97     14.62     21.61    553.85
# 8    518.67    642.12   1590.98   1394.80     14.62     21.61    553.69
# 9    518.67    641.71   1591.24   1400.46     14.62     21.61    553.59
#
#    sensor_8  sensor_9  sensor_10  ...  sensor_12_rollstd5  sensor_13_rollstd5  \
# 0   2388.06   9046.19        1.3  ...                 NaN                 NaN
# 1   2388.04   9044.07        1.3  ...            0.438406            0.035355
# 2   2388.08   9052.94        1.3  ...            0.404475            0.026458
# 3   2388.11   9049.48        1.3  ...            0.495950            0.029439
# 4   2388.06   9055.15        1.3  ...            0.432574            0.025884
# 5   2388.02   9049.68        1.3  ...            0.425417            0.023452
# 6   2388.02   9059.13        1.3  ...            0.425652            0.021679
# 7   2388.00   9040.80        1.3  ...            0.429919            0.021679
# 8   2388.05   9046.46        1.3  ...            0.341101            0.008944
# 9   2388.05   9051.70        1.3  ...            0.358260            0.014142
#
#    sensor_14_rollstd5  sensor_15_rollstd5  sensor_16_rollstd5  \
# 0                 NaN                 NaN                 NaN
# 1            5.041671            0.008697                 0.0
# 2            3.717450            0.007640                 0.0
# 3            3.050906            0.028117                 0.0
# 4            2.651326            0.025953                 0.0
# 5            0.958697            0.025727                 0.0
# 6            0.643141            0.023476                 0.0
# 7            1.149274            0.022477                 0.0
# 8            3.205438            0.020740                 0.0
# 9            2.883881            0.020493                 0.0
#
#    sensor_17_rollstd5  sensor_18_rollstd5  sensor_19_rollstd5  \
# 0                 NaN                 NaN                 NaN
# 1            0.000000                 0.0                 0.0
# 2            1.154701                 0.0                 0.0
# 3            1.000000                 0.0                 0.0
# 4            1.095445                 0.0                 0.0
# 5            1.140175                 0.0                 0.0
# 6            1.140175                 0.0                 0.0
# 7            0.836660                 0.0                 0.0
# 8            0.836660                 0.0                 0.0
# 9            0.836660                 0.0                 0.0
#
#    sensor_20_rollstd5  sensor_21_rollstd5
# 0                 NaN                 NaN
# 1            0.042426            0.003253
# 2            0.055076            0.044573
# 3            0.076322            0.037977
# 4            0.073621            0.033498
# 5            0.051186            0.031436
# 6            0.086718            0.021634
# 7            0.086487            0.034405
# 8            0.077136            0.038939
# 9            0.062849            0.058103
#
# [10 rows x 63 columns]

# %%
## Normalize all sensor columns and rolling feature columns (per sensor globally for simplicity)
features_to_scale = [col for col in df.columns if ('sensor_' in col) or ('roll' in col)]

## StandardScaler (mean=0, std=1)
scaler = StandardScaler()
df_scaled = df.copy()
df_scaled[features_to_scale] = scaler.fit_transform(df_scaled[features_to_scale])
df_scaled.head()
# Out:
#    engine_id  cycle  op_setting_1  op_setting_2  op_setting_3  sensor_1  \
# 0          1      1       -0.0007       -0.0004         100.0       0.0
# 1          1      2        0.0019       -0.0003         100.0       0.0
# 2          1      3       -0.0043        0.0003         100.0       0.0
# 3          1      4        0.0007        0.0000         100.0       0.0
# 4          1      5       -0.0019       -0.0002         100.0       0.0
#
#    sensor_2  sensor_3  sensor_4      sensor_5  ...  sensor_17_rollmean5  \
# 0 -1.721725 -0.134255 -0.925936 -1.776357e-15  ...            -0.926028
# 1 -1.061780  0.211528 -0.643726 -1.776357e-15  ...            -0.926028
# 2 -0.661813 -0.413166 -0.525953 -1.776357e-15  ...            -1.453702
# 3 -0.661813 -1.261314 -0.784831 -1.776357e-15  ...            -1.321784
# 4 -0.621816 -1.251528 -0.301518 -1.776357e-15  ...            -1.084330
#
#    sensor_17_rollstd5  sensor_18_rollmean5  sensor_18_rollstd5  \
# 0                 NaN                  0.0                 NaN
# 1           -2.638069                  0.0                 0.0
# 2            0.786588                  0.0                 0.0
# 3            0.327771                  0.0                 0.0
# 4            0.610846                  0.0                 0.0
#
#    sensor_19_rollmean5  sensor_19_rollstd5  sensor_20_rollmean5  \
# 0                  0.0                 NaN             1.564172
# 1                  0.0                 0.0             1.367661
# 2                  0.0                 0.0             1.192984
# 3                  0.0                 0.0             0.991014
# 4                  0.0                 0.0             0.896034
#
#    sensor_20_rollstd5  sensor_21_rollmean5  sensor_21_rollstd5
# 0                 NaN             1.379118                 NaN
# 1           -1.534785             1.404213           -2.630752
# 2           -1.166192             1.123794           -0.599129
# 3           -0.547098             1.064600           -0.923458
# 4           -0.625804             1.095643           -1.143645
#
# [5 rows x 68 columns]

# %%
# Confirma scaled feature distribution
df_scaled[features_to_scale].describe().T[['mean', 'std']]
# Out:
#                              mean       std
# sensor_1             0.000000e+00  0.000000
# sensor_2             6.410348e-14  1.000024
# sensor_3            -4.959437e-14  1.000024
# sensor_4             9.285169e-16  1.000024
# sensor_5            -1.776357e-15  0.000000
# ...                           ...       ...
# sensor_19_rollstd5   0.000000e+00  0.000000
# sensor_20_rollmean5 -2.134211e-14  1.000024
# sensor_20_rollstd5   1.958829e-16  1.000024
# sensor_21_rollmean5 -2.148263e-14  1.000024
# sensor_21_rollstd5   1.515843e-16  1.000024
#
# [63 rows x 2 columns]

# %% [markdown]
# # Feature Matrix Construction & Validation

# %%
# Select all numeric columns except engine_id and cycle as feature matrix
exclude_cols = ['engine_id', 'cycle']
feature_cols = [col for col in df_scaled.columns if col not in exclude_cols]

# check for missing values
print("Missing values per feature column:")
print(df_scaled[feature_cols].isnull().sum())
# Out:
# Missing values per feature column:
# op_setting_1             0
# op_setting_2             0
# op_setting_3             0
# sensor_1                 0
# sensor_2                 0
#                       ...
# sensor_19_rollstd5     100
# sensor_20_rollmean5      0
# sensor_20_rollstd5     100
# sensor_21_rollmean5      0
# sensor_21_rollstd5     100
# Length: 66, dtype: int64

# %%
# Final feature matrix
X = df_scaled[feature_cols]
print(f"Final feature matrix shape: {X.shape}")
X.head()
# Out:
# Final feature matrix shape: (20631, 66)
#    op_setting_1  op_setting_2  op_setting_3  sensor_1  sensor_2  sensor_3  \
# 0       -0.0007       -0.0004         100.0       0.0 -1.721725 -0.134255
# 1        0.0019       -0.0003         100.0       0.0 -1.061780  0.211528
# 2       -0.0043        0.0003         100.0       0.0 -0.661813 -0.413166
# 3        0.0007        0.0000         100.0       0.0 -0.661813 -1.261314
# 4       -0.0019       -0.0002         100.0       0.0 -0.621816 -1.251528
#
#    sensor_4      sensor_5  sensor_6  sensor_7  ...  sensor_17_rollmean5  \
# 0 -0.925936 -1.776357e-15  0.141683  1.121141  ...            -0.926028
# 1 -0.643726 -1.776357e-15  0.141683  0.431930  ...            -0.926028
# 2 -0.525953 -1.776357e-15  0.141683  1.008155  ...            -1.453702
# 3 -0.784831 -1.776357e-15  0.141683  1.222827  ...            -1.321784
# 4 -0.301518 -1.776357e-15  0.141683  0.714393  ...            -1.084330
#
#    sensor_17_rollstd5  sensor_18_rollmean5  sensor_18_rollstd5  \
# 0                 NaN                  0.0                 NaN
# 1           -2.638069                  0.0                 0.0
# 2            0.786588                  0.0                 0.0
# 3            0.327771                  0.0                 0.0
# 4            0.610846                  0.0                 0.0
#
#    sensor_19_rollmean5  sensor_19_rollstd5  sensor_20_rollmean5  \
# 0                  0.0                 NaN             1.564172
# 1                  0.0                 0.0             1.367661
# 2                  0.0                 0.0             1.192984
# 3                  0.0                 0.0             0.991014
# 4                  0.0                 0.0             0.896034
#
#    sensor_20_rollstd5  sensor_21_rollmean5  sensor_21_rollstd5
# 0                 NaN             1.379118                 NaN
# 1           -1.534785             1.404213           -2.630752
# 2           -1.166192             1.123794           -0.599129
# 3           -0.547098             1.064600           -0.923458
# 4           -0.625804             1.095643           -1.143645
#
# [5 rows x 66 columns]

# %% [markdown]
# #### Feature Engineering Summary
#
# - Features Created:
#   - Aggregate statistics per engine: mean, std, min, max for each sensor (static features)
#   - Rolling-window features (window=5): rolling mean and std trend for each sensor per cycle/engine (dynamic features)
#   - All raw, aggregate, and rolling features scaled using StandardScaler (zero mean, unit variance)
#
# - Validation:
#   - Verified presence of missing values in the final feature set.
#   - Final feature matrix contains [INSERT VALUE: X.shape] engineered features per cycle.
