# %% [markdown]
# # Streamlit
#
# streamlit is an open-source Python framework designed to help data scientists and AI/ML engineers quickly build and share interactive web applications with very few lines of code. It enables creation of dynamic data apps, dashboards, and user interfaces without requiring expertise in front-end technologies like HTML, CSS, or JavaScript.
#
#
# *   **Definition**: streamlit lets you transform Python scripts into interactive web apps rapidly. This makes it ideal for building dashboards, reports, machine learning model demos, and data visualization tools in a simple and Pythonic way. By running the Python script with Streamlit, it launches a local web server and renders the app in a browser, allowing live interaction and instant feedback.
#
# * **Key Features**:
#
#
# 1.   Simple and Pythonic: Write apps with pure Python code using an intuitive API.
#
# 2. Fast Prototyping: Build interactive data apps in minutes rather than weeks.
#
# 3. Live Editing: Apps update instantly as you modify the script.
#
# 4. Widgets for Interaction: Includes buttons, sliders, text input, file uploaders, and more to capture user input.
#
# 5. Rich Media Support: Supports text, markdown, code, LaTeX, images, audio, and video display.
#
# 6. Layout Options: Columns, sidebar, expanders for flexible user interface design.
#
# 7. State Management: Maintains widget and app state across user interactions.
#
# 8. Animations and Feedback: Progress bars, spinners, and balloons to enhance user experience.
#
# 9. Data Visualization: Easily integrate charts and dataframes.
#
# 10. Open Source and Extensible: Active community with many add-ons and integrations.
#
# 11. Deployment Options: Can be deployed locally, on cloud platforms, or enterprise solutions like Streamlit Cloud or Snowflake.
#
# These features make Streamlit a popular choice for quickly transforming Python data scripts into professional interactive applications with minimal effort.

# %%
# %pip install streamlit
# Out:
# Collecting streamlit
#   Downloading streamlit-1.50.0-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<6,>=4.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<7,>=4.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (8.2.1)
# Requirement already satisfied: numpy<3,>=1.23 in /usr/local/lib/python3.12/dist-packages (from streamlit) (2.0.2)
# Requirement already satisfied: packaging<26,>=20 in /usr/local/lib/python3.12/dist-packages (from streamlit) (25.0)
# Requirement already satisfied: pandas<3,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (2.2.2)
# Requirement already satisfied: pillow<12,>=7.1.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (11.3.0)
# Requirement already satisfied: protobuf<7,>=3.20 in /usr/local/lib/python3.12/dist-packages (from streamlit) (5.29.5)
# Requirement already satisfied: pyarrow>=7.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (18.1.0)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.12/dist-packages (from streamlit) (2.32.4)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (8.5.0)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.12/dist-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (4.15.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in /usr/local/lib/python3.12/dist-packages (from streamlit) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /usr/local/lib/python3.12/dist-packages (from streamlit) (3.1.45)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in /usr/local/lib/python3.12/dist-packages (from streamlit) (6.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.12/dist-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (4.25.1)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.12/dist-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (2.5.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->streamlit) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->streamlit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->streamlit) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->streamlit) (2025.8.3)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.27.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Downloading streamlit-1.50.0-py3-none-any.whl (10.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 60.0 MB/s eta 0:00:00
# Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 105.0 MB/s eta 0:00:00
# Installing collected packages: pydeck, streamlit
# Successfully installed pydeck-0.9.1 streamlit-1.50.0

# %% [markdown]
# # 1. Title, Header, Subheader, and Text

# %%
import streamlit as st # Import streamlit library
st.title('This is a Title')
st.header('This is a Header')
st.subheader('This is a Subheader')
st.text('This is a standard text message.')
# Out:
# 2025-10-03 13:53:30.794 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:53:30.795 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:53:30.797 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:53:30.798 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:53:30.799 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:53:30.800 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:53:30.802 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:53:30.802 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:53:30.804 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:53:30.804 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:53:30.806 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:53:30.806 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %% [markdown]
# #2. Markdown, Code, LaTeX, and Write

# %%
st.markdown('# Markdown Title\nSome **bold** and _italic_ text.')
st.code('print("Hello, Streamlit!")', language='python')
st.latex('e^{i\\pi} + 1 = 0')
st.write('Write can display various data types including text, numbers, and dataframes')
# Out:
# 2025-10-03 13:53:51.039 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:53:51.040 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:53:51.041 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:53:51.042 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:53:51.043 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:53:51.044 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:53:51.046 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:53:51.046 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:53:51.047 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:53:51.048 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:53:51.049 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:53:51.050 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %% [markdown]
# # 3. Interactive Widgets Section
# This block demonstrates various input widgets that capture user interactions.

# %%
if st.button('Click me'):
    st.write('Button clicked!')
# Out:
# 2025-10-03 13:54:31.298 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:54:31.300 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:54:31.301 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:54:31.303 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:54:31.304 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:54:31.306 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
if st.checkbox('Check me'):
    st.write('Checkbox is checked')
# Out:
# 2025-10-03 13:54:33.979 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:54:33.981 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:54:33.983 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:54:33.984 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:54:33.984 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:54:33.985 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
choice = st.radio('Choose one:', ['Option 1', 'Option 2'])
st.write(f'You chose {choice}')
# Out:
# 2025-10-03 13:54:35.843 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:54:35.847 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:54:35.848 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:54:35.851 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:54:35.852 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:54:35.853 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:54:35.853 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:54:35.855 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:54:35.857 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:54:35.858 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
option = st.selectbox('Select:', ['A', 'B', 'C'])
st.write(f'Selected {option}')
# Out:
# 2025-10-03 13:48:09.692 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:48:09.695 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:48:09.696 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:48:09.697 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:48:09.700 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:48:09.701 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:48:09.701 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:48:09.703 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:48:09.705 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:48:09.706 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
options = st.multiselect('Select multiple:', ['A', 'B', 'C'])
st.write(f'Selected {options}')
# Out:
# 2025-10-03 13:48:21.945 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:48:21.946 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:48:21.947 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:48:21.948 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:48:21.949 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:48:21.949 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:48:21.950 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:48:21.951 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:48:21.952 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
val = st.slider('Slide me', 0, 100, 25)
st.write(f'Slider value {val}')
# Out:
# 2025-10-03 13:48:35.070 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:48:35.072 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:48:35.073 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:48:35.073 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:48:35.074 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:48:35.075 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:48:35.076 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:48:35.077 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:48:35.077 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
text = st.text_input('Enter text:')
st.write(f'Your input: {text}')
# Out:
# 2025-10-03 13:49:00.634 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:49:00.636 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:49:00.638 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:49:00.639 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:49:00.640 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:49:00.641 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:49:00.642 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:49:00.642 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:49:00.644 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:49:00.645 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
num = st.number_input('Enter a number:', 0, 100)
st.write(f'Number: {num}')
# Out:
# 2025-10-03 13:49:11.403 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:49:11.411 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:49:11.421 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:49:11.427 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:49:11.432 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:49:11.439 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:49:11.443 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:49:11.453 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:49:11.464 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:49:11.472 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
date = st.date_input('Pick a date')
st.write(f'Date selected: {date}')
# Out:
# 2025-10-03 13:49:23.462 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:49:23.464 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:49:23.467 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:49:23.468 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:49:23.470 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:49:23.471 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:49:23.472 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:49:23.475 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:49:23.476 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:49:23.477 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
time_val = st.time_input('Pick a time')
st.write(f'Time selected: {time_val}')
# Out:
# 2025-10-03 13:49:34.820 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:49:34.822 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:49:34.823 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:49:34.824 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:49:34.825 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:49:34.826 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:49:34.827 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:49:34.828 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:49:34.829 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:49:34.830 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %% [markdown]
# #4. File and Media Inputs

# %%
file = st.file_uploader('Upload file')
if file:
    st.write(f'Filename: {file.name}')
# Out:
# 2025-10-03 13:50:46.495 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:50:46.499 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:50:46.504 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:50:46.506 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:50:46.507 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:50:46.509 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
img = st.camera_input('Take a picture')
if img:
    st.image(img)
# Out:
# 2025-10-03 13:50:57.992 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:50:57.998 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:50:58.001 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:50:58.005 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:50:58.007 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:50:58.011 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
color = st.color_picker('Pick a color')
st.write(f'Color: {color}')
# Out:
# 2025-10-03 13:51:11.541 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:51:11.541 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:51:11.543 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:51:11.544 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:51:11.546 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:51:11.548 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:51:11.549 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:51:11.552 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:51:11.553 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %% [markdown]
# # 5. Layout & Animation

# %%
col1, col2 = st.columns(2)
col1.write('Column 1')
col2.write('Column 2')
# Out:
# 2025-10-03 13:51:36.849 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:51:36.851 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:51:36.851 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:51:36.853 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:51:36.854 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:51:36.856 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:51:36.857 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:51:36.858 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:51:36.859 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
with st.expander('Expand me'):
    st.write('Hidden text here')
# Out:
# 2025-10-03 13:51:47.919 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:51:47.921 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:51:47.922 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:51:47.924 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
with st.sidebar:
    st.write('Sidebar content here')
# Out:
# 2025-10-03 13:51:57.729 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:51:57.731 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:51:57.732 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
st.balloons()
# Out:
# 2025-10-03 13:52:08.078 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:08.080 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:08.081 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
import time
with st.spinner('Loading...'):
    time.sleep(2)
st.write('Done!')
# Out:
# 2025-10-03 13:52:18.256 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:18.263 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:18.267 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:18.270 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:18.776 Thread 'Thread-4': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:18.778 Thread 'Thread-4': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:18.779 Thread 'Thread-4': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:20.276 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:20.277 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:20.279 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:20.280 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:20.282 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:20.283 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
progress = st.progress(0)
for i in range(100):
    progress.progress(i + 1)
st.write('Progress complete')
# Out:
# 2025-10-03 13:52:33.519 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.520 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.522 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.524 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.525 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.526 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.527 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.527 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.529 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.530 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.531 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.532 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.533 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.533 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.534 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.536 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.536 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.538 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.539 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.540 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.541 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.541 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.542 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.543 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.545 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.545 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.546 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.548 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.549 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.549 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.551 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.551 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.552 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.554 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.554 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.555 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.556 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.556 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.558 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.558 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.561 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.561 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.562 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.563 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.563 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.564 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.565 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.570 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.572 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.572 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.574 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.575 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.576 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.577 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.578 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.580 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.581 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.581 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.582 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.584 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.585 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.586 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.588 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.588 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.591 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.592 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.593 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.594 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.596 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.596 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.598 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.599 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.600 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.601 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.601 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.603 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.603 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.604 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.606 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.607 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.607 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.608 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.608 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.609 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.611 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.611 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.612 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.613 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.613 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.615 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.615 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.616 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.617 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.619 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.619 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.620 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.621 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.621 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.622 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.623 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.624 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.625 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.626 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.626 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.628 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.628 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.629 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.630 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.631 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.631 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.632 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.633 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.635 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.636 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.637 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.638 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.638 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.639 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.639 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.640 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.641 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.641 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.643 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.643 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.644 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.644 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.645 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.646 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.648 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.648 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.649 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.649 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.650 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.650 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.651 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.651 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.652 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.653 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.653 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.654 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.656 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.657 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.658 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.658 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.659 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.659 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.661 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.663 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.664 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.665 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.666 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.668 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.668 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.669 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.671 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.674 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.675 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.675 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.679 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.683 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.686 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.687 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.690 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.691 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.693 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.695 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.696 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.697 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.698 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.699 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.700 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.701 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.702 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.703 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.703 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.704 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.705 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.706 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.706 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.708 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.708 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.709 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.710 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.710 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.711 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.711 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.713 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.713 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.714 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.714 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.716 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.716 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.717 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.718 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.718 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.720 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.720 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.721 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.721 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.722 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.723 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.725 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.725 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.726 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.727 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.727 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.728 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.730 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.731 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.731 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.732 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.732 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.733 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.734 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.734 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.735 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.735 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.736 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.737 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.737 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.739 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.739 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.740 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.740 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.741 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.741 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.743 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.743 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.743 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.746 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.746 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.747 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.747 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.748 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.748 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.749 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.749 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.750 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.753 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.753 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.754 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.754 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.755 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.756 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.757 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.757 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.758 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.758 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.759 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.760 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.762 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.763 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.763 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.764 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.764 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.765 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.766 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.766 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.767 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.767 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.768 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.769 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.770 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.770 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.771 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.771 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.772 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.775 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.775 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.776 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.776 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.778 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.779 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.781 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.781 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.784 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.784 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.785 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.785 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.786 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.786 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.787 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.787 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.788 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.789 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.789 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.790 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.791 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.792 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.792 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.793 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.798 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.798 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.799 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.799 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.800 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.803 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.803 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.804 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.804 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.805 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.805 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.806 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.811 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.811 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:33.812 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
st.metric(label='Temperature', value='70 °F', delta='-5 °F')
# Out:
# 2025-10-03 13:52:45.558 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:45.565 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 13:52:45.573 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()
